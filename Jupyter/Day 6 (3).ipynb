# %% [markdown]
# ### First Step to read data from the file
# **import libraries**
# - import pandas
# - import seaborn
# - import matplotlib

# %% [markdown]
# ### 1- CatPlot

# %% [markdown]
# ### First Read data from File

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
day5
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %% [markdown]
# ### After Read data from file then plot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", data=day5)
#     ci="sd", palette="dark", alpha=.6, height=6,kind="bar"
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Add Confidence Interval Element

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", data=day5)
#      palette="dark", alpha=.6, height=6,kind="bar"
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Add Palette Element

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", data=day5)
#       alpha=.6, height=6,kind="bar"
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Add Alpha Element

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", alpha=.6, data=day5)
#        height=6,kind="bar"
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Add Height Element

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", alpha=.6,
    height=6, data=day5)
#        kind="bar"
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Add Kind Element

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", alpha=.6,
    height=6, kind="bar", data=day5)
#        
# )
# g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Run despine command on my data

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", alpha=.6,
    height=6, kind="bar", data=day5)
g.despine(left=True)
# g.set_axis_labels("", "Body mass (g)")
# g.legend.set_title("")

# %% [markdown]
# ### Labels Axis

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", alpha=.6,
    height=6, kind="bar", data=day5)
g.despine(left=True)
g.set_axis_labels("Location", "Age in Years")
# g.legend.set_title("")

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested barplot by species and sex
g = sns.catplot(
    x="Location", y="Age (years)-Float/Int", hue="Gender", ci="sd", palette="dark", alpha=.6,
    height=6, kind="bar", data=day5)
g.despine(left=True)
g.set_axis_labels("Location", "Age in Years")
g.legend.set_title("")

# %% [markdown]
# ### 2- BoxPlot

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Gender", y="Your Weight in kg? (float)",
            hue="Marital Status?", data=day5)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Your Weight in kg? (float)'>

# %% [markdown]
# ### Add Palette Element in boxPlot

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Gender", y="Your Weight in kg? (float)",
            hue="Marital Status?", palette=["k", "b"], data=day5)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Your Weight in kg? (float)'>

# %% [markdown]
# ### Apply despine function on data of box plot

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="Gender", y="Your Weight in kg? (float)",
            hue="Marital Status?", palette=["k", "b"], data=day5)
sns.despine(offset=10, trim=True)

# %% [markdown]
# ### 3- Violin Plot

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Draw a nested boxplot to show bills by day and time
sns.violinplot(x="Gender", y="Your Weight in kg? (float)",
            hue="Marital Status?", palette={"Yes": "r", "No": ".85"}, split=True, inner="quart", linewidth=1,
               data=day5)
sns.despine(left=True)

# %% [markdown]
# ### 4 - Relplot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Compute a correlation matrix and convert to long-form
corr_mat = day5.corr().stack().reset_index(name="correlation")
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3",
    hue="Your Weight in kg? (float)", size="Height in cm? Freelancer- (Float)",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),data=day5)

# # Tweak the figure to finalize
# g.set(xlabel="", ylabel="", aspect="equal")

# %% [markdown]
# ### Add Axis Element in Relplot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

corr_mat = day5.corr().stack().reset_index(name="correlation")
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3",
    hue="Your Weight in kg? (float)", size="Height in cm? Freelancer- (Float)",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),data=day5)

# # Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
#g.despine(left=True, bottom=True)

# %% [markdown]
# ### Apply Despine Function on Relplot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

corr_mat = day5.corr().stack().reset_index(name="correlation")
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3",
    hue="Your Weight in kg? (float)", size="Height in cm? Freelancer- (Float)",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),data=day5)

# # Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)

# %% [markdown]
# ### Apply Margins Function

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

corr_mat = day5.corr().stack().reset_index(name="correlation")
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3",
    hue="Your Weight in kg? (float)", size="Height in cm? Freelancer- (Float)",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),data=day5)

# # Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)

# %% [markdown]
# ### Apply Label and Rotation function

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

corr_mat = day5.corr().stack().reset_index(name="correlation")
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3",
    hue="Your Weight in kg? (float)", size="Height in cm? Freelancer- (Float)",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),data=day5)

# # Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

corr_mat = day5.corr().stack().reset_index(name="correlation")
# Draw each cell as a scatter point with varying size and color
g = sns.relplot(x="Light kitni der band hti hy? int", y="How many hours you code a day? (int) e.g: 5,4,3",
    hue="Your Weight in kg? (float)", size="Height in cm? Freelancer- (Float)",
    palette="vlag", hue_norm=(-1, 1), edgecolor=".7",
    height=10, sizes=(50, 250), size_norm=(-.2, .8),data=day5)

# # Tweak the figure to finalize
g.set(xlabel="", ylabel="", aspect="equal")
g.despine(left=True, bottom=True)
g.ax.margins(.02)
for label in g.ax.get_xticklabels():
    label.set_rotation(90)
for artist in g.legend.legendHandles:
    artist.set_edgecolor(".7")

# %% [markdown]
# ### 5- Joint Plot

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")

rs = np.random.RandomState(6)
x = rs.gamma(3, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x=x, y=y, kind="hex", color="#940a84")

# %% [markdown]
# ### 6- Histoplot
# - First import different libraries
# - then read data from the file
# - show read data

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
day5
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %% [markdown]
# ### Show Read data in the form of histoplot

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", hue="Where do you live?", data=day5)
#     multiple="stack",
#     palette="light:m_r",
#     edgecolor=".3",
#     linewidth=.5,
#     log_scale=True,
# )
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Count'>

# %% [markdown]
# ### Add Multiple element

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", hue="Where do you live?",  multiple="stack", data=day5)
#    
#     palette="light:m_r",
#     edgecolor=".3",
#     linewidth=.5,
#     log_scale=True,
# )
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Count'>

# %% [markdown]
# ### Add Palette Element

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", hue="Where do you live?",  multiple="stack",
             palette="light:m_r", data=day5)
#    
#     
#     edgecolor=".3",
#     linewidth=.5,
#     log_scale=True,
# )
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Count'>

# %% [markdown]
# ### Add Edge Color Element

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", hue="Where do you live?",  multiple="stack",
             palette="light:m_r", edgecolor=".3", data=day5)
#    
#     
#     
#     linewidth=.5,
#     log_scale=True,
# )
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Count'>

# %% [markdown]
# ### Add Linewidth

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", hue="Where do you live?",  multiple="stack",
             palette="light:m_r", edgecolor=".3", linewidth=.5, data=day5)
#    
#     
#     
#     
#     log_scale=True,
# )
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Count'>

# %% [markdown]
# ### Adjust Scale

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", hue="Where do you live?",  multiple="stack",
             palette="light:m_r", edgecolor=".3", linewidth=.5, log_scale=False, data=day5)
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(x="Light kitni der band hti hy? int", y="Location", hue="Where do you live?",  multiple="stack",
             palette="light:m_r", edgecolor=".3", linewidth=.5, log_scale=False, data=day5)
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Location'>

# %% [markdown]
# ### 7- BoxPlot
# - import libraries
# - first read data
# - show data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", data=day5)
#             whis=[0, 100], width=.6, palette="vlag")
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Location'>

# %% [markdown]
# ### Add whis Element

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", whis=[0, 100], data=day5)
#              width=.6, palette="vlag")
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Location'>

# %% [markdown]
# ### Add Width Element

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", whis=[0, 100],
            width=.6, data=day5)
#               palette="vlag")
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Location'>

# %% [markdown]
# ### Add Palette Element

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", whis=[0, 100],
            width=.6, palette="husl", data=day5)
# Out:
# <AxesSubplot:xlabel='Light kitni der band hti hy? int', ylabel='Location'>

# %% [markdown]
# ### Add Axis Grid function

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", whis=[0, 100],
            width=.6, palette="husl", data=day5)
# Tweak the visual presentation
ax.xaxis.grid(True)
# ax.set(ylabel="")
# sns.despine(trim=True, left=True)

# %% [markdown]
# ### Set Label

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", whis=[0, 100],
            width=.6, palette="husl", data=day5)
# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
# sns.despine(trim=True, left=True)
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ### Add Despine Function

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Light kitni der band hti hy? int", y="Location", whis=[0, 100],
            width=.6, palette="husl", data=day5)
# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)

# %% [markdown]
# ### 8- StripPlot
# - Import Libraries
# - Read Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
day5
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %% [markdown]
# ### After Read data show in the form of graph

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?", data=day5)
#               data=iris, dodge=True, alpha=.25, zorder=1)
# Out:
# <AxesSubplot:xlabel='Age (years)-Float/Int', ylabel='Gender'>

# %% [markdown]
# ### Add Dodge Element

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?", dodge=True, data=day5)
#                 alpha=.25, zorder=1)
# Out:
# <AxesSubplot:xlabel='Age (years)-Float/Int', ylabel='Gender'>

# %% [markdown]
# ### Add Alpha Element

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?", dodge=True, alpha=.25, data=day5)
#                  zorder=1)
# Out:
# <AxesSubplot:xlabel='Age (years)-Float/Int', ylabel='Gender'>

# %% [markdown]
# ### Add zorder element

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?", dodge=True, alpha=.25,
              zorder=1, data=day5)
# Out:
# <AxesSubplot:xlabel='Age (years)-Float/Int', ylabel='Gender'>

# %% [markdown]
# ### After Strip Plot now we are plot point plot in the same code

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?", dodge=True, alpha=.25,
              zorder=1, data=day5)
# Show the conditional means, aligning each pointplot in the
# center of the strips by adjusting the width allotted to each
# category (.8 by default) by the number of hue levels
sns.pointplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?",
              data=day5, dodge=.8 - .8 / 3,
              join=False, palette="dark",
              markers="d", scale=.75, ci=None)
# Out:
# <AxesSubplot:xlabel='Age (years)-Float/Int', ylabel='Gender'>

# %% [markdown]
# ### Add Different Functions to modify plot

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# "Melt" the dataset to "long-form" or "tidy" representation
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Initialize the figure
f, ax = plt.subplots()
sns.despine(bottom=True, left=True)

# Show each observation with a scatterplot
sns.stripplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?", dodge=True, alpha=.25,
              zorder=1, data=day5)
# Show the conditional means, aligning each pointplot in the
# center of the strips by adjusting the width allotted to each
# category (.8 by default) by the number of hue levels
sns.pointplot(x="Age (years)-Float/Int", y="Gender", hue="Where do you live?",
              data=day5, dodge=.8 - .8 / 3,
              join=False, palette="dark",
              markers="d", scale=.75, ci=None)
# Improve the legend
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[3:], labels[3:], title="",
          handletextpad=0, columnspacing=1,
          loc="lower right", ncol=3, frameon=True)

# %% [markdown]
# ### 9- Joint Plot
# - Import Libraries
# - Read Data
# - Show Graph

# %%
import seaborn as sns
sns.set_theme(style="ticks")

# Load the penguins dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Show the joint distribution using kernel density estimation
g = sns.jointplot(x="Your Weight in kg? (float)", y="Height in cm? Freelancer- (Float)", hue="Gender",
    kind="kde", data=day5)

# %% [markdown]
# ### 10- BoxenPlot
# - import libraries
# - read data
# - set theme

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
day5
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %% [markdown]
# ### After reading data from the file now implement in the form of graph

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
field_of_study_ranking = ["Enginnering", "CS/IT", "Mathematics", "Natural Sciences"]

sns.boxenplot(x="field_of_study", y="Age (years)-Float/Int",
              color="r", order=field_of_study_ranking,
              scale="linear", data=day5)
# Out:
# <AxesSubplot:xlabel='field_of_study', ylabel='Age (years)-Float/Int'>

# %% [markdown]
# ### 11- Implot
# - import libraries
# - read data
# - set theme
# - change palette according to our choice
# - show read data in the form of graph

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load the example Titanic dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Make a custom palette with gendered colors
pal = dict(male="#160b96", female="#d10869")

# Show the survival probability as a function of age and sex
g = sns.lmplot(x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3",
               col="Gender", hue="Gender", data=day5)
#                palette=pal, y_jitter=.02, logistic=True, truncate=False)

# %% [markdown]
# ### Add already make palette element

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load the example Titanic dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Make a custom palette with gendered colors
pal = dict(Male="#160b96", Female="#d10869")

# Show the survival probability as a function of age and sex
g = sns.lmplot(x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3",
               col="Gender", hue="Gender", palette=pal, data=day5)
#                 y_jitter=.02, logistic=True, truncate=False)

# %% [markdown]
# ### Add Jitter Element

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load the example Titanic dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Make a custom palette with gendered colors
pal = dict(Male="#160b96", Female="#d10869")

# Show the survival probability as a function of age and sex
g = sns.lmplot(x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3",
               col="Gender", hue="Gender", palette=pal, y_jitter=.02, data=day5)
#                  logistic=True, truncate=False)

# %% [markdown]
# ### Add Logistic Element

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load the example Titanic dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Make a custom palette with gendered colors
pal = dict(Male="#160b96", Female="#d10869")

# Show the survival probability as a function of age and sex
g = sns.lmplot(x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3",
               col="Gender", hue="Gender", palette=pal, y_jitter=.02, logistic=True, data=day5)
#                   truncate=False)
# Out:
# C:\Users\Yasir Mehmood\anaconda3\lib\site-packages\statsmodels\genmod\families\links.py:188: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# C:\Users\Yasir Mehmood\anaconda3\lib\site-packages\statsmodels\genmod\families\links.py:188: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)

# %% [markdown]
# ### Now its final

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load the example Titanic dataset
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Make a custom palette with gendered colors
pal = dict(Male="#160b96", Female="#d10869")

# Show the survival probability as a function of age and sex
g = sns.lmplot(x="Age (years)-Float/Int", y="How many hours you code a day? (int) e.g: 5,4,3",
               col="Gender", hue="Gender", palette=pal, y_jitter=.02, logistic=True, truncate=False, data=day5)
# Out:
# C:\Users\Yasir Mehmood\anaconda3\lib\site-packages\statsmodels\genmod\families\links.py:188: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# C:\Users\Yasir Mehmood\anaconda3\lib\site-packages\statsmodels\genmod\families\links.py:188: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
