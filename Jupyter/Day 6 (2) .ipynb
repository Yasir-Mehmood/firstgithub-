# %% [markdown]
# ### First Step to read data from the file
# **import libraries**
# - import pandas
# - import seaborn
# - import matplotlib

# %% [markdown]
# ### First Read Data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")
day5
# Out:
#      Gender  Location    Age Qualification_completed    field_of_study  \
# 0      Male  Pakistan  36-40                 Masters  Natural Sciences
# 1      Male  Pakistan  26-30               Bachelors             CS/IT
# 2      Male  Pakistan  31-35                 Masters       Enginnering
# 3    Female  Pakistan  31-35                 Masters             CS/IT
# 4    Female  Pakistan  26-30                 Masters       Enginnering
# ..      ...       ...    ...                     ...               ...
# 370    Male  Pakistan  26-30                 Masters       Enginnering
# 371    Male  Pakistan  31-35               Bachelors       Enginnering
# 372    Male  Pakistan  21-25               Bachelors             CS/IT
# 373    Male  Pakistan  26-30                 Masters       Enginnering
# 374  Female  Pakistan  31-35                 Masters       Mathematics
#
#            Purpose_for_chilla What are you? Blood group   \
# ...

# %% [markdown]
# ### Add X and Y axis

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years", data=day5)
#     hue="coherence", size="choice", col="align",
#     kind="line", size_order=["T1", "T2"], palette=palette,
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add Hue Element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", data=day5)
#      size="choice", col="align",
#     kind="line", size_order=["T1", "T2"], palette=palette,
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add another element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", data=day5)
#       col="align",
#     kind="line", size_order=["T1", "T2"], palette=palette,
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", data=day5)
#       
#     kind="line", size_order=["T1", "T2"], palette=palette,
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add Kind element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", kind="line", data=day5)
#       
#      size_order=["T1", "T2"], palette=palette,
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add size order element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", kind="line",
            size_order=["Pakistan", "India"],data=day5)
#       
#       palette=palette,
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add Palette Element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", kind="line",
            size_order=["Pakistan", "India"], palette="tab10", data=day5)
#       
#       
#     height=5, aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add Highet Element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", kind="line",
            size_order=["Pakistan", "India"], palette="tab10", height=5, data=day5)
#       
#       
#      aspect=.75, facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add Aspect Element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", kind="line",
            size_order=["Pakistan", "India"], palette="tab10", height=5, aspect=.75, data=day5)
#       
#       
#       facet_kws=dict(sharex=False),
# )

# %% [markdown]
# ### Add Facet Element

# %%
import seaborn as sns
sns.set_theme(style="ticks")

day5=pd.read_csv("C:/Users/Yasir Mehmood/Downloads/Python Programs/Chilla_data2_for_plots.csv")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(x="Light kitni der band hti hy? int", y="Research/Working experience (Float/Int) years",
            hue="Age (years)-Float/Int", size="Location", col="Are you Vaccinated?", kind="line",
            size_order=["Pakistan", "India"], palette="tab10", height=5, aspect=.75, facet_kws=dict(sharex=False), data=day5)
